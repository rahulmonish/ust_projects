# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Location=r'D:\Assignment-master\April 7\Camera _Updated.txt'


df= pd.read_csv(Location,sep=";")

print(df)
# Out:
#                        Model Releasedate Max resolution Low resolution  \
# 0                     STRING      DOUBLE         DOUBLE         DOUBLE
# 1           Agfa ePhoto 1280        1997         1024.0          640.0
# 2           Agfa ePhoto 1680        1998         1280.0          640.0
# 3           Agfa ePhoto CL18        2000          640.0            0.0
# 4           Agfa ePhoto CL30        1999         1152.0          640.0
# 5     Agfa ePhoto CL30 Clik!        1999         1152.0          640.0
# 6           Agfa ePhoto CL45        2001         1600.0          640.0
# 7           Agfa ePhoto CL50        1999         1280.0          640.0
# 8        Canon PowerShot 350        1997          640.0            0.0
# 9        Canon PowerShot 600        1996          832.0          640.0
# 10       Canon PowerShot A10        2001         1280.0         1024.0
# 11      Canon PowerShot A100        2002         1280.0         1024.0
# ...

# %%
print(df.dtypes)
# Out:
# Model                      object
# Releasedate                object
# Max resolution             object
# Low resolution             object
# Effective pixels           object
# Zoom wide (W)              object
# Zoom tele (T)              object
# Normal focus range         object
# Macro focus range          object
# Storage included           object
# Weight (inc. batteries)    object
# Dimensions                 object
# Price                      object
# dtype: object

# %%
for i in range(25):
    print(df.loc[i,"Model"],"\t",df.loc[i,"Releasedate"],"\t",df.loc[i,"Price"])
# Out:
# STRING 	 DOUBLE 	 DOUBLE
# Agfa ePhoto 1280 	 1997 	 179.0
# Agfa ePhoto 1680 	 1998 	 179.0
# Agfa ePhoto CL18 	 2000 	 179.0
# Agfa ePhoto CL30 	 1999 	 269.0
# Agfa ePhoto CL30 Clik! 	 1999 	 1299.0
# Agfa ePhoto CL45 	 2001 	 179.0
# Agfa ePhoto CL50 	 1999 	 179.0
# Canon PowerShot 350 	 1997 	 149.0
# Canon PowerShot 600 	 1996 	 139.0
# Canon PowerShot A10 	 2001 	 139.0
# Canon PowerShot A100 	 2002 	 139.0
# Canon PowerShot A20 	 2001 	 139.0
# Canon PowerShot A200 	 2002 	 139.0
# Canon PowerShot A30 	 2002 	 139.0
# Canon PowerShot A300 	 2003 	 139.0
# Canon PowerShot A310 	 2004 	 139.0
# Canon PowerShot A40 	 2002 	 139.0
# Canon PowerShot A400 	 2004 	 139.0
# Canon PowerShot A410 	 2005 	 139.0
# Canon PowerShot A420 	 2006 	 139.0
# Canon PowerShot A430 	 2006 	 139.0
# Canon PowerShot A450 	 2007 	 139.0
# Canon PowerShot A460 	 2007 	 139.0
# Canon PowerShot A5 	 1998 	 149.0

# %%
plt.plot(df['Price'],df['Releasedate'],'o')
plt.title('Price Vs Release Date')
plt.xlabel('Price')
plt.ylabel('Release Date')
# Out:
# Text(0,0.5,'Release Date')

# %%
plt.plot(df['Dimensions'],df['Price'],"o")
plt.title('Dimensions Vs Price')
plt.xlabel('Dimensions')
plt.ylabel('Price')
# Out:
# Text(0,0.5,'Price')

# %%
plt.plot(df['Model'],df['Price'],"o")
plt.title('Dimensions Vs Price')
plt.xlabel('Dimensions')
plt.ylabel('Price')
# Out:
# Text(0,0.5,'Price')
